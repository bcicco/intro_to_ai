# %%
import pandas as pd

df = pd.read_parquet("../data/processed/scats_wide.parquet")
df.head()
# Out:
#                      2000__BURWOOD_HWY E of WARRIGAL_RD  \
# timestamp
# 2006-10-01 00:00:00                                94.0
# 2006-10-01 00:15:00                                82.0
# 2006-10-01 00:30:00                                49.0
# 2006-10-01 00:45:00                                64.0
# 2006-10-01 01:00:00                                48.0
#
#                      2000__TOORAK_RD W of WARRIGAL_RD  \
# timestamp
# 2006-10-01 00:00:00                             115.0
# 2006-10-01 00:15:00                              99.0
# 2006-10-01 00:30:00                              94.0
# 2006-10-01 00:45:00                              86.0
# 2006-10-01 01:00:00                              75.0
#
#                      2000__WARRIGAL_RD N of TOORAK_RD  \
# timestamp
# 2006-10-01 00:00:00                              46.0
# 2006-10-01 00:15:00                              41.0
# 2006-10-01 00:30:00                              42.0
# ...
